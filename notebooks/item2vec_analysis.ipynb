# %% [markdown]
# # Item2vec Recommendation System Analysis
#
# This notebook demonstrates the Item2vec recommendation system and provides analysis tools.

# %%
import sys
sys.path.append('src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
import plotly.express as px
import plotly.graph_objects as go

from data.data_utils import generate_synthetic_data
from models.item2vec import Item2Vec
from models.baselines import PopularityRecommender, UserKNNRecommender, ItemKNNRecommender
from evaluation.metrics import evaluate_model
from utils.seed import set_seed
